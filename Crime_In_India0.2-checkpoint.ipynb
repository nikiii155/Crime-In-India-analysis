# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# load csv file#

# %%
df = pd.read_csv("Crimes_in_India_2001-2013.csv")
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9835     Lakshadweep    LAKSHADWEEP  2013       0                  0
# 9836     Lakshadweep       ZZ TOTAL  2013       0                  0
# 9837      Puducherry       KARAIKAL  2013       6                  3
# 9838      Puducherry     PUDUCHERRY  2013      25                  8
# 9839      Puducherry       ZZ TOTAL  2013      31                 11
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
df.tail()
# Out:
#          STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 9835  Lakshadweep  LAKSHADWEEP  2013       0                  0
# 9836  Lakshadweep     ZZ TOTAL  2013       0                  0
# 9837   Puducherry     KARAIKAL  2013       6                  3
# 9838   Puducherry   PUDUCHERRY  2013      25                  8
# 9839   Puducherry     ZZ TOTAL  2013      31                 11
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 9835                                          0     2               0
# 9836                                          0     2               0
# 9837                                          0     6               0
# 9838                                          2    11               0
# 9839                                          2    17               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 9835           2                       0  ...      1                   5
# ...

# %%
df.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9840.000000  9840.000000     9840.000000
# mean                                    9.754878    55.456098        0.005488
# std                                    58.733349   201.690457        0.111218
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df.shape
# Out:
# (9840, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
# ...

# %%
pd.isnull(df).sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# ...

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
# we can the that rape and other rape same data so we are deleting that#

# %%
df.drop('OTHER RAPE', axis=1, inplace=True)

# %%
# Custodial rape also not have any data seems#

# %%
df.drop("CUSTODIAL RAPE", axis=1, inplace=True)

# %%
# important of girls from foregiegn countries have no data #

# %%
df.drop("IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES", axis=1, inplace=True)

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  KIDNAPPING & ABDUCTION  \
# 0                                         17    50                      46
# 1                                          1    23                      53
# 2                                          2    27                      59
# 3                                          1    20                      25
# 4                                          1    23                      49
#
#    KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# 0                                           30
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE',
#        'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
list(df["STATE/UT"].unique())
# Out:
# ['ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'ASSAM',
#  'BIHAR',
#  'CHHATTISGARH',
#  'GOA',
#  'GUJARAT',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'JAMMU & KASHMIR',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'ODISHA',
#  'PUNJAB',
#  'RAJASTHAN',
#  'SIKKIM',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'UTTARAKHAND',
#  'WEST BENGAL',
#  'A & N ISLANDS',
#  'CHANDIGARH',
#  'D & N HAVELI',
#  'DAMAN & DIU',
#  'DELHI UT',
#  'LAKSHADWEEP',
#  'PUDUCHERRY',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
# ...

# %%
# These are the unique state/ut --------------------------------------------------

# %%
list(df["DISTRICT"].unique())
# Out:
# ['ADILABAD',
#  'ANANTAPUR',
#  'CHITTOOR',
#  'CUDDAPAH',
#  'EAST GODAVARI',
#  'GUNTAKAL RLY.',
#  'GUNTUR',
#  'HYDERABAD CITY',
#  'KARIMNAGAR',
#  'KHAMMAM',
#  'KRISHNA',
#  'KURNOOL',
#  'MAHABOOBNAGAR',
#  'MEDAK',
#  'NALGONDA',
#  'NELLORE',
#  'NIZAMABAD',
#  'PRAKASHAM',
#  'RANGA REDDY',
#  'SECUNDERABAD RLY.',
#  'SRIKAKULAM',
#  'VIJAYAWADA',
#  'VIJAYAWADA RLY.',
#  'VISAKHA RURAL',
#  'VISAKHAPATNAM',
#  'VIZIANAGARAM',
#  'WARANGAL',
#  'WEST GODAVARI',
#  'TOTAL',
#  'CHANGLANG',
#  'DIBANG VALLEY',
#  'KAMENG EAST',
#  'KAMENG WEST',
#  'LOHIT',
#  'PAPUM PARE',
#  'SIANG EAST',
#  'SIANG UPPER',
#  'SIANG WEST',
#  'SUBANSIRI LOWER',
#  'SUBANSIRI UPPER',
#  'TAWANG',
#  'TIRAP',
#  'BARPETA',
#  'BONGAIGAON',
#  'C.I.D.',
#  'CACHAR',
#  'DARRANG',
#  'DHEMAJI',
#  'DHUBRI',
#  'DIBRUGARH',
#  'G.R.P.',
#  'GOALPARA',
#  'GOLAGHAT',
#  'GUWAHATI CITY',
#  'HAILAKANDI',
#  'JORHAT',
#  'KAMRUP',
#  'KARBI ANGLONG',
#  'KARIMGANJ',
#  'KOKRAJHAR',
# ...

# %%
# this is unique district- -------------------------------------------------

# %%
df["DISTRICT"].value_counts()
# Out:
# DISTRICT
# TOTAL              408
# G.R.P.              49
# SOUTH               41
# NORTH               41
# WEST                39
#                   ...
# MIDNAPUR             1
# G.R.P. AJMER         1
# G.R.P. JODHPUR       1
# A and N ISLANDS      1
# METRO RAIL           1
# Name: count, Length: 828, dtype: int64

# %%
 # distirct count ----------------------------

# %%
df.nunique()
# Out:
# STATE/UT                                                 70
# DISTRICT                                                828
# YEAR                                                     13
# MURDER                                                  498
# ATTEMPT TO MURDER                                       539
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               174
# RAPE                                                    449
# KIDNAPPING & ABDUCTION                                  591
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             507
# KIDNAPPING AND ABDUCTION OF OTHERS                      327
# DACOITY                                                 237
# PREPARATION AND ASSEMBLY FOR DACOITY                    200
# ROBBERY                                                 486
# BURGLARY                                                962
# THEFT                                                  1844
# AUTO THEFT                                             1196
# ...

# %%
# nunique ----------------------

# %%
df.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  \
# count                                9840.000000  9840.000000
# mean                                    9.754878    55.456098
# std                                    58.733349   201.690457
# min                                     0.000000     0.000000
# 25%                                     0.000000     8.000000
# 50%                                     2.000000    21.000000
# 75%                                     6.000000    43.000000
# ...

# %%
# now we don't have any other rape, Custodial rape , and  important of girls from foregiegn countries column#

# %%
ax = sns.countplot(x = "YEAR", data = df , color = "brown")
plt.savefig("YEAR")

# %%
ax = sns.countplot(x = "YEAR", data = df, color = 'purple')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# according to year cases are increase #

# %%
# murder cases in every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["MURDER"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()
plt.savefig("MURDER")

# %%
# attempt to murder every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["ATTEMPT TO MURDER"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()
plt.savefig("ATTEMPT TO MURDER")

# %%
#CULPABLE HOMICIDE NOT AMOUNTING TO MURDER cases every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["CULPABLE HOMICIDE NOT AMOUNTING TO MURDER"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()
plt.savefig("CULPABLE HOMICIDE NOT AMOUNTING TO MURDER")

# %%
# rape cases every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["RAPE"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()
plt.savefig("RAPE")

# %%
#KIDNAPPING & ABDUCTION every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["KIDNAPPING & ABDUCTION"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()
plt.savefig("KIDNAPPING & ABDUCTION")

# %%
#KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLs every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
#DACOITY every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["DACOITY"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
#PREPARATION AND ASSEMBLY FOR DACOITY every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["PREPARATION AND ASSEMBLY FOR DACOITY"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# robbery every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["ROBBERY"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# burglary every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["BURGLARY"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# theft every year percentage #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["THEFT"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# auto theft evrey year percentage #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["AUTO THEFT"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# other theft every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["OTHER THEFT"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# roits every year#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["RIOTS"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# criminsl breach of trust every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["CRIMINAL BREACH OF TRUST"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# cheating cases in evrey year percentage #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["CHEATING"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# COUNTERFIETING cases in every year #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["COUNTERFIETING"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# arson cases in every year percentage #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["ARSON"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# hurt/grevious hurt every year percentage #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["HURT/GREVIOUS HURT"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# dowrey deaths in every year percentage#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["DOWRY DEATHS"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
#ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY every year percentage #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
#INSULT TO MODESTY OF WOME  EVERY YEAR PERCENTAGE #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["INSULT TO MODESTY OF WOMEN"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
#CRUELTY BY HUSBAND OR HIS RELATIVE EVERYYEAR PERCENTAGE #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["CRUELTY BY HUSBAND OR HIS RELATIVES"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# CAUSING DEATH BY NEGLIGENCE EVERY YEAR PERCENTAGE #

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["CAUSING DEATH BY NEGLIGENCE"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# OTHER IPC CRIME EVREY YEAR PERCENTAGE#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["OTHER IPC CRIMES"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
# TOTAL IPC CRIMES EVERY YEAR PERCENTAGE#

# %%
plt.figure(figsize=(6,9))
df.groupby("YEAR") ["TOTAL IPC CRIMES"].sum().plot.pie(autopct = '%2.0f%%')
plt.show()

# %%
 # THESE ARE THE DIFFIRENT COMPARITION WITH YEARS #

# %%
# THERE IS STATE WISE COMPARISSION #

# %%
# MURDERS , 10 HIGHEST STATES #

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["MURDER"].sum().sort_values(by = "MURDER",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y ="MURDER" ,color= 'r')
plt.savefig("MURDER")

# %%
#ATTEMPT TO MURDER, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["ATTEMPT TO MURDER"].sum().sort_values(by = "ATTEMPT TO MURDER",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y ="ATTEMPT TO MURDER" ,color= 'GRAY')
plt.savefig("ATTEMPT TO MURDER")

# %%
#CULPABLE HOMICIDE NOT AMOUNTING TO MURDER, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["CULPABLE HOMICIDE NOT AMOUNTING TO MURDER"].sum().sort_values(by = "CULPABLE HOMICIDE NOT AMOUNTING TO MURDER",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y ="CULPABLE HOMICIDE NOT AMOUNTING TO MURDER" ,color= 'pink')

plt.savefig("CULPABLE HOMICIDE NOT AMOUNTING TO MURDER")

# %%
# RAPE , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["RAPE"].sum().sort_values(by = "RAPE",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y ="RAPE")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='RAPE'>

# %%
#KIDNAPPING & ABDUCTION, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["KIDNAPPING & ABDUCTION"].sum().sort_values(by = "KIDNAPPING & ABDUCTION",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y ="KIDNAPPING & ABDUCTION" ,color = "green")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='KIDNAPPING & ABDUCTION'>

# %%
#KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS"].sum().sort_values(by = "KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS", color = "coral")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS'>

# %%
#DACOITY , 10 HIGHEST STATE#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["DACOITY"].sum().sort_values(by = "DACOITY",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "DACOITY", color = "plum")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='DACOITY'>

# %%
#PREPARATION AND ASSEMBLY FOR DACOITY, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["PREPARATION AND ASSEMBLY FOR DACOITY"].sum().sort_values(by = "PREPARATION AND ASSEMBLY FOR DACOITY",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "PREPARATION AND ASSEMBLY FOR DACOITY", color = "maroon")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='PREPARATION AND ASSEMBLY FOR DACOITY'>

# %%
# ROBBERY, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["ROBBERY"].sum().sort_values(by = "ROBBERY",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "ROBBERY", color = "violet")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='ROBBERY'>

# %%
# BURGLARY, 10 HIGHEST STATES #

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["BURGLARY"].sum().sort_values(by = "BURGLARY",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "BURGLARY", color = "gold")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='BURGLARY'>

# %%
# THEFT, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["THEFT"].sum().sort_values(by = "THEFT",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "THEFT", color = "khaki")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='THEFT'>

# %%
# AUTO THEFT, 10 HIGHEST STATES #

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["AUTO THEFT"].sum().sort_values(by = "AUTO THEFT",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "AUTO THEFT", color = "cyan")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='AUTO THEFT'>

# %%
# OTHER THEFT, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["OTHER THEFT"].sum().sort_values(by = "OTHER THEFT",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "OTHER THEFT", color = "magenta")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='OTHER THEFT'>

# %%
# ROITS, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["RIOTS"].sum().sort_values(by = "RIOTS",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "RIOTS", color = "DarkSeaGreen")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='RIOTS'>

# %%
# CRIMINAL BREACH OF TRUST , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["CRIMINAL BREACH OF TRUST"].sum().sort_values(by = "CRIMINAL BREACH OF TRUST",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "CRIMINAL BREACH OF TRUST", color = "LightSeaGreen")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='CRIMINAL BREACH OF TRUST'>

# %%
# CHEATING , 10 HIGHEST THEFT #

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["CHEATING"].sum().sort_values(by = "CHEATING",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "CHEATING", color = "LightSlateGray")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='CHEATING'>

# %%
#COUNTERFIETING, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["COUNTERFIETING"].sum().sort_values(by = "COUNTERFIETING",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "COUNTERFIETING", color = "MidnightBlue")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='COUNTERFIETING'>

# %%
# ARSON, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["ARSON"].sum().sort_values(by = "ARSON",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "ARSON", color = "LimeGreen")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='ARSON'>

# %%
#HURT/GREVIOUS HURT , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["HURT/GREVIOUS HURT"].sum().sort_values(by = "HURT/GREVIOUS HURT",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "HURT/GREVIOUS HURT", color = "PaleVioletRed")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='HURT/GREVIOUS HURT'>

# %%
#DOWREY DEATHS , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["DOWRY DEATHS"].sum().sort_values(by = "DOWRY DEATHS",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "DOWRY DEATHS", color = "DarkTurquoise")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='DOWRY DEATHS'>

# %%
#ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"].sum().sort_values(by = "ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY", color = "IndianRed")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY'>

# %%
#INSULT TO MODESTY OF WOMEN, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["INSULT TO MODESTY OF WOMEN"].sum().sort_values(by = "INSULT TO MODESTY OF WOMEN",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "INSULT TO MODESTY OF WOMEN", color = "Indigo")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='INSULT TO MODESTY OF WOMEN'>

# %%
# CRUELTY BY HUSBAND OR HIS RELATIVES, 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["CRUELTY BY HUSBAND OR HIS RELATIVES"].sum().sort_values(by = "CRUELTY BY HUSBAND OR HIS RELATIVES",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "CRUELTY BY HUSBAND OR HIS RELATIVES", color = "DarkGoldenrod")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='CRUELTY BY HUSBAND OR HIS RELATIVES'>

# %%
#CAUSING DEATH BY NEGLIGENCE , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["CAUSING DEATH BY NEGLIGENCE"].sum().sort_values(by = "CAUSING DEATH BY NEGLIGENCE",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "CAUSING DEATH BY NEGLIGENCE", color = "DarkSalmon")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='CAUSING DEATH BY NEGLIGENCE'>

# %%
# OTHER IPC CRIMES , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["OTHER IPC CRIMES"].sum().sort_values(by = "OTHER IPC CRIMES",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "OTHER IPC CRIMES", color = "DarkOliveGreen")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='OTHER IPC CRIMES'>

# %%
# TOTAL IPC CRIMES , 10 HIGHEST STATES#

# %%
ac = df.groupby(["STATE/UT"],as_index =False)["TOTAL IPC CRIMES"].sum().sort_values(by = "TOTAL IPC CRIMES",ascending =False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
sns.barplot(data= ac,x = "STATE/UT", y = "TOTAL IPC CRIMES", color = "DarkCyan")
# Out:
# <Axes: xlabel='STATE/UT', ylabel='TOTAL IPC CRIMES'>

# %%
 # STATE WISE COMPARISION , WE CAN SEE THAT THE DIFFIRENT CASES HAVE HIGHESGT STATES#

# %%
# NOW W ARE COUNTING THE TOTAL CASES VALUES EVERY UNIQUE STATES#

# %%
crimes=['MURDER', 'ATTEMPT TO MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE',
       'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
       'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
       'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
       'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
       'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
       'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES']

first_state=pd.DataFrame()
for i in crimes:
    first_state_crimes=df.groupby(['STATE/UT'])[i].sum()
    first_state[i]=first_state_crimes
first_state["Total"]=first_state.sum(axis=1)
first_state=first_state.sort_values(by="Total",ascending=False)
first_state
# Out:
#                 MURDER  ATTEMPT TO MURDER  \
# STATE/UT
# MAHARASHTRA      65534              41178
# MADHYA PRADESH   56798              58916
# ANDHRA PRADESH   63512              44840
# TAMIL NADU       40254              53194
# UTTAR PRADESH   130886             121040
# ...                ...                ...
# LAKSHADWEEP          6                 12
# A&N Islands         12                  8
# D&N Haveli           6                  4
# Daman & Diu         18                  2
# Lakshadweep          0                  0
#
#                 CULPABLE HOMICIDE NOT AMOUNTING TO MURDER   RAPE  \
# STATE/UT
# MAHARASHTRA                                          2818  35972
# MADHYA PRADESH                                       3668  72174
# ANDHRA PRADESH                                       3526  26958
# TAMIL NADU                                            686  13904
# UTTAR PRADESH                                       34532  38116
# ...

# %%
first_state.head(5)
# Out:
#                 MURDER  ATTEMPT TO MURDER  \
# STATE/UT
# MAHARASHTRA      65534              41178
# MADHYA PRADESH   56798              58916
# ANDHRA PRADESH   63512              44840
# TAMIL NADU       40254              53194
# UTTAR PRADESH   130886             121040
#
#                 CULPABLE HOMICIDE NOT AMOUNTING TO MURDER   RAPE  \
# STATE/UT
# MAHARASHTRA                                          2818  35972
# MADHYA PRADESH                                       3668  72174
# ANDHRA PRADESH                                       3526  26958
# TAMIL NADU                                            686  13904
# UTTAR PRADESH                                       34532  38116
#
#                 KIDNAPPING & ABDUCTION  \
# STATE/UT
# MAHARASHTRA                      30202
# MADHYA PRADESH                   23916
# ANDHRA PRADESH                   42478
# TAMIL NADU                       30606
# UTTAR PRADESH                   118532
#
# ...

# %%
first_state.tail()
# Out:
#              MURDER  ATTEMPT TO MURDER  \
# STATE/UT
# LAKSHADWEEP       6                 12
# A&N Islands      12                  8
# D&N Haveli        6                  4
# Daman & Diu      18                  2
# Lakshadweep       0                  0
#
#              CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  \
# STATE/UT
# LAKSHADWEEP                                          0    14
# A&N Islands                                          2    54
# D&N Haveli                                           2    10
# Daman & Diu                                          8    16
# Lakshadweep                                          0     4
#
#              KIDNAPPING & ABDUCTION  \
# STATE/UT
# LAKSHADWEEP                       2
# A&N Islands                      28
# D&N Haveli                       26
# Daman & Diu                      26
# Lakshadweep                       0
#
#              KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# STATE/UT
# ...

# %%
# BY THIS WE FIND HIGHEST CRIMES SATES AND LOWEST CRIMES STATES #

# %%
# NOW WE CAN SEE THAT THAT GRAPH#

# %%
first_state.groupby("STATE/UT")["Total"].sum().sort_values(ascending= False).plot.bar()
# Out:
# <Axes: xlabel='STATE/UT'>

# %%
#top 5  highest crime state  ---  maharashtra, madhayapradesh, andhrapradesh, tamilnadu, uttrapradesh & 
#top 5 lowest crime states  ----  LAKSHADWEEP, A&N Islands, D&N Haveli, Daman & Diu, Lakshadweep

# %%
# total number of MAHARASHTRA cases #

# %%
df_up1= first_state.loc[first_state.index=="MAHARASHTRA"].sort_values( by="Total",ascending= True)
dfupT=df_up1.T.drop("Total")
dfupT
# Out:
# STATE/UT                                            MAHARASHTRA
# MURDER                                                    65534
# ATTEMPT TO MURDER                                         41178
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                  2818
# RAPE                                                      35972
# KIDNAPPING & ABDUCTION                                    30202
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS               21706
# KIDNAPPING AND ABDUCTION OF OTHERS                         8496
# DACOITY                                                   16350
# PREPARATION AND ASSEMBLY FOR DACOITY                       7314
# ROBBERY                                                   75438
# BURGLARY                                                 371234
# THEFT                                                   1113614
# AUTO THEFT                                               336464
# OTHER THEFT                                              777150
# ...

# %%
# total number of MADHYA PRADESH cases #

# %%
df_up2 = first_state.loc[first_state.index == "MADHYA PRADESH" ].sort_values(by = "Total" ,  ascending = True)
dfupt2 = df_up2.T.drop("Total")
dfupt2
# Out:
# STATE/UT                                            MADHYA PRADESH
# MURDER                                                       56798
# ATTEMPT TO MURDER                                            58916
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                     3668
# RAPE                                                         72174
# KIDNAPPING & ABDUCTION                                       23916
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                  18486
# KIDNAPPING AND ABDUCTION OF OTHERS                            5430
# DACOITY                                                       3310
# PREPARATION AND ASSEMBLY FOR DACOITY                          3082
# ROBBERY                                                      44628
# BURGLARY                                                    274692
# THEFT                                                       527720
# AUTO THEFT                                                  200224
# ...

# %%
# total number of  ANDHRA PRADESH cases #

# %%
df_up3 = first_state.loc[first_state.index== "ANDHRA PRADESH"].sort_values(by ="Total" , ascending = True )
dfupt3 =  df_up3.T.drop("Total")
dfupt3
# Out:
# STATE/UT                                            ANDHRA PRADESH
# MURDER                                                       63512
# ATTEMPT TO MURDER                                            44840
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                     3526
# RAPE                                                         26958
# KIDNAPPING & ABDUCTION                                       42478
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                  29872
# KIDNAPPING AND ABDUCTION OF OTHERS                           12606
# DACOITY                                                       3974
# PREPARATION AND ASSEMBLY FOR DACOITY                           160
# ROBBERY                                                      15210
# BURGLARY                                                    194672
# THEFT                                                       574380
# AUTO THEFT                                                  145288
# ...

# %%
# total number of tamil nadu cases#

# %%
df_up4 = first_state.loc[first_state.index== "TAMIL NADU"].sort_values(by ="Total" , ascending = True )
dfupt4 =  df_up4.T.drop("Total")
dfupt4
# Out:
# STATE/UT                                            TAMIL NADU
# MURDER                                                   40254
# ATTEMPT TO MURDER                                        53194
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                  686
# RAPE                                                     13904
# KIDNAPPING & ABDUCTION                                   30606
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS              24872
# KIDNAPPING AND ABDUCTION OF OTHERS                        5734
# DACOITY                                                   2474
# PREPARATION AND ASSEMBLY FOR DACOITY                       614
# ROBBERY                                                  22544
# BURGLARY                                                106678
# THEFT                                                   370320
# AUTO THEFT                                               99306
# OTHER THEFT                                             271014
# ...

# %%
# total number of uttar pradesh cases #

# %%
df_up5 = first_state.loc[first_state.index== "UTTAR PRADESH"].sort_values(by ="Total" , ascending = True )
dfupt5 =  df_up5.T.drop("Total")
dfupt5
# Out:
# STATE/UT                                            UTTAR PRADESH
# MURDER                                                     130886
# ATTEMPT TO MURDER                                          121040
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                   34532
# RAPE                                                        38116
# KIDNAPPING & ABDUCTION                                     118532
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 95180
# KIDNAPPING AND ABDUCTION OF OTHERS                          23352
# DACOITY                                                      9618
# PREPARATION AND ASSEMBLY FOR DACOITY                         1876
# ROBBERY                                                     61534
# BURGLARY                                                   131174
# THEFT                                                      624094
# AUTO THEFT                                                 292502
# ...

# %%
# lowest state in crimes#

# %%
#LAKSHADWEEP#

# %%
df_low1 =  first_state.loc[first_state.index=="LAKSHADWEEP"].sort_values(by = "Total", ascending = True)
df_low1t = df_low1.T.drop("Total")
df_low1t
# Out:
# STATE/UT                                            LAKSHADWEEP
# MURDER                                                        6
# ATTEMPT TO MURDER                                            12
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                     0
# RAPE                                                         14
# KIDNAPPING & ABDUCTION                                        2
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                   2
# KIDNAPPING AND ABDUCTION OF OTHERS                            0
# DACOITY                                                       6
# PREPARATION AND ASSEMBLY FOR DACOITY                          0
# ROBBERY                                                       0
# BURGLARY                                                     72
# THEFT                                                       226
# AUTO THEFT                                                   22
# OTHER THEFT                                                 204
# ...

# %%
#A&N Islands#

# %%
df_low2 =  first_state.loc[first_state.index=="A&N Islands"].sort_values(by = "Total", ascending = True)
df_low2t = df_low2.T.drop("Total")
df_low2t
# Out:
# STATE/UT                                            A&N Islands
# MURDER                                                       12
# ATTEMPT TO MURDER                                             8
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                     2
# RAPE                                                         54
# KIDNAPPING & ABDUCTION                                       28
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                  24
# KIDNAPPING AND ABDUCTION OF OTHERS                            4
# DACOITY                                                       2
# PREPARATION AND ASSEMBLY FOR DACOITY                          0
# ROBBERY                                                       2
# BURGLARY                                                     84
# THEFT                                                        74
# AUTO THEFT                                                    4
# OTHER THEFT                                                  70
# ...

# %%
#D&N Haveli #

# %%
df_low3 =  first_state.loc[first_state.index=="D&N Haveli"].sort_values(by = "Total", ascending = True)
df_low3t = df_low3.T.drop("Total")
df_low3t
# Out:
# STATE/UT                                            D&N Haveli
# MURDER                                                       6
# ATTEMPT TO MURDER                                            4
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                    2
# RAPE                                                        10
# KIDNAPPING & ABDUCTION                                      26
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 22
# KIDNAPPING AND ABDUCTION OF OTHERS                           4
# DACOITY                                                      2
# PREPARATION AND ASSEMBLY FOR DACOITY                         0
# ROBBERY                                                      0
# BURGLARY                                                    42
# THEFT                                                      116
# AUTO THEFT                                                  52
# OTHER THEFT                                                 64
# ...

# %%
#Daman & Di #

# %%
df_low4 =  first_state.loc[first_state.index=="Daman & Diu"].sort_values(by = "Total", ascending = True)
df_low4t = df_low4.T.drop("Total")
df_low4t
# Out:
# STATE/UT                                            Daman & Diu
# MURDER                                                       18
# ATTEMPT TO MURDER                                             2
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                     8
# RAPE                                                         16
# KIDNAPPING & ABDUCTION                                       26
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                  12
# KIDNAPPING AND ABDUCTION OF OTHERS                           14
# DACOITY                                                      12
# PREPARATION AND ASSEMBLY FOR DACOITY                          0
# ROBBERY                                                       2
# BURGLARY                                                     38
# THEFT                                                        76
# AUTO THEFT                                                   50
# OTHER THEFT                                                  26
# ...

# %%
#"Lakshadweep#

# %%
df_low5 =  first_state.loc[first_state.index=="Lakshadweep"].sort_values(by = "Total", ascending = True)
df_low5t = df_low5.T.drop("Total")
df_low5t
# Out:
# STATE/UT                                            Lakshadweep
# MURDER                                                        0
# ATTEMPT TO MURDER                                             0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                     0
# RAPE                                                          4
# KIDNAPPING & ABDUCTION                                        0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                   0
# KIDNAPPING AND ABDUCTION OF OTHERS                            0
# DACOITY                                                       0
# PREPARATION AND ASSEMBLY FOR DACOITY                          0
# ROBBERY                                                       0
# BURGLARY                                                      4
# THEFT                                                        16
# AUTO THEFT                                                    0
# OTHER THEFT                                                  16
# ...

# %% [markdown]
#                                                         ## THANK YOU ##
